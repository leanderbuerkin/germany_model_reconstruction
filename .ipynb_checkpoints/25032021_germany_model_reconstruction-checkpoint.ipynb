# %%
# for reading .xlsx-files
import pandas as pd

import json

# %% [markdown]
# # Corona Fälle und Inzidenz nach Landkreis und Tag

# %%
data = list()
if True:
    timestamp = pd.read_excel("RKI_direkt\Archiv_Fallzahlen_und_7-Tage-Inzidenzen_nach_Landkreis_(seit_19112020).xlsx",
                              skiprows = 4,
                              sheet_name = 1,
                              header = 0)
    data.append(timestamp)
data
# Out:
# [                       LK  Fälle    Inzidenz  LK_Nr
#  0            LK Ahrweiler    203  156.050613   7131
#  1    LK Aichach-Friedberg    187  138.873417   9771
#  2      LK Alb-Donau-Kreis    231  117.213664   8425
#  3     LK Altenburger Land    137  153.255848  16077
#  4         LK Altenkirchen     75   58.227553   7132
#  ..                    ...    ...         ...    ...
#  407              SK Worms     77   92.169208   7319
#  408          SK Wuppertal    688  193.748240   5124
#  409           SK Würzburg    125   97.706630   9663
#  410        SK Zweibrücken     34   99.435557   7320
#  411    StadtRegion Aachen    999  179.345309   5334
#
#  [412 rows x 4 columns]]

# %%
data[0]
# Out:
#                        LK  Fälle    Inzidenz  LK_Nr
# 0            LK Ahrweiler    203  156.050613   7131
# 1    LK Aichach-Friedberg    187  138.873417   9771
# 2      LK Alb-Donau-Kreis    231  117.213664   8425
# 3     LK Altenburger Land    137  153.255848  16077
# 4         LK Altenkirchen     75   58.227553   7132
# ..                    ...    ...         ...    ...
# 407              SK Worms     77   92.169208   7319
# 408          SK Wuppertal    688  193.748240   5124
# 409           SK Würzburg    125   97.706630   9663
# 410        SK Zweibrücken     34   99.435557   7320
# 411    StadtRegion Aachen    999  179.345309   5334
#
# [412 rows x 4 columns]

# %% [markdown]
# # Alle einzelnen Corona-Fälle

# %%
with open("RKI_COVID19.geojson", "r") as file:
       data2 = json.loads(file.read())

# %%
data2["features"][0]['properties']['AnzahlFall']
# Out:
# 1

# %%
acc = 0
for dp in data2["features"]:
    acc += dp['properties']['AnzahlFall']

# %%
acc
# Out:
# 2734474

# %% [markdown]
# # Einmaliger Datensatz mit Koordinaten und Geometrien

# %%
data3 = pd.read_csv("RKI_Corona_Landkreise.csv")

# %%
data3
# Out:
#      OBJECTID  ADE   GF  BSG     RS     AGS        SDV_RS  \
# 0           1  4.0  4.0  1.0   1001  1001.0  1.001000e+10
# 1           2  4.0  4.0  1.0   1002  1002.0  1.002000e+10
# 2           3  4.0  4.0  1.0   1003  1003.0  1.003000e+10
# 3           4  4.0  4.0  1.0   1004  1004.0  1.004000e+10
# 4           5  4.0  4.0  1.0   1051  1051.0  1.051004e+10
# ..        ...  ...  ...  ...    ...     ...           ...
# 407       411  NaN  NaN  NaN  11005     NaN           NaN
# 408       412  NaN  NaN  NaN  11006     NaN           NaN
# 409       413  NaN  NaN  NaN  11001     NaN           NaN
# 410       414  NaN  NaN  NaN  11002     NaN           NaN
# 411       415  NaN  NaN  NaN  11007     NaN           NaN
#
#                                  GEN               BEZ   IBZ  ...   EWZ_BL  \
# 0                          Flensburg  Kreisfreie Stadt  40.0  ...  2903773
# 1                               Kiel  Kreisfreie Stadt  40.0  ...  2903773
# 2                             Lübeck  Kreisfreie Stadt  40.0  ...  2903773
# 3                         Neumünster  Kreisfreie Stadt  40.0  ...  2903773
# 4                       Dithmarschen             Kreis  42.0  ...  2903773
# ..                               ...               ...   ...  ...      ...
# 407                   Berlin Spandau            Bezirk   NaN  ...  3669491
# 408       Berlin Steglitz-Zehlendorf            Bezirk   NaN  ...  3669491
# 409                     Berlin Mitte            Bezirk   NaN  ...  3669491
# 410  Berlin Friedrichshain-Kreuzberg            Bezirk   NaN  ...  3669491
# 411      Berlin Tempelhof-Schöneberg            Bezirk   NaN  ...  3669491
#
#     cases7_bl_per_100k  cases7_bl  death7_bl  cases7_lk  death7_lk  \
# 0            59.784288       1736          1         88          0
# 1            59.784288       1736          1        117          1
# 2            59.784288       1736          1        131          0
# 3            59.784288       1736          1         57          0
# 4            59.784288       1736          1         70          0
# ..                 ...        ...        ...        ...        ...
# 407         111.323342       4085          4        274          0
# 408         111.323342       4085          4        256          0
# 409         111.323342       4085          4        577          1
# 410         111.323342       4085          4        240          0
# 411         111.323342       4085          4        339          3
#
#      cases7_per_100k_txt  AdmUnitId SHAPE_Length SHAPE_Area
# 0                   97,6       1001     0.524721   0.006873
# 1                   47,4       1002     1.274684   0.015507
# 2                   60,5       1003     1.834534   0.028928
# 3                   71,1       1004     0.663262   0.009808
# 4                   52,6       1051     3.073353   0.196087
# ..                   ...        ...          ...        ...
# 407                114,6      11005     0.719318   0.012292
# 408                 84,7      11006     0.791122   0.013552
# 409                153,8      11001     0.438594   0.005218
# 410                 85,1      11002     0.404632   0.002700
# 411                 99,2      11007     0.534689   0.007011
#
# [412 rows x 47 columns]
